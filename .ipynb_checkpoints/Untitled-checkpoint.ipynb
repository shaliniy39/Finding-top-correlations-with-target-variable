# %%
#How to see only top correlated variables with target variable

# %%
#Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
# import Housing.csv
#here we are using housing data as an example
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#seperating numerical data from categorical data for plotting correlation
num_cols =  train.select_dtypes(include=[np.number]).columns.tolist()
len(num_cols)
# Out:
# 38

# %%
#Correlations of only numerical data
plt.figure(figsize = (16, 10))
sns.heatmap(train[num_cols].corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# As the correlation matrix here is very messy, its good to only top correlation with the target variable

# %%
# correlation matrix
cor_numVar = train[num_cols].corr()

# %%
#Here I want to see correlations which are more than 0.5, free to choose the required number

corHigh = cor_numVar[abs(cor_numVar['SalePrice']) > 0.5]

# %%
#Numeric variables having highest correlations
corHigh.index
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#        'SalePrice'],
#       dtype='object')

# %%
#High correlations
plt.figure(figsize = (16, 10))
sns.heatmap(train[corHigh.index].corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# Now, this is clear and gives a good idea of dataset
#
# Hope it helps
